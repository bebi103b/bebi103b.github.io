# %% [markdown]
# # E7. To be completed after lesson 20
#
# <hr />

# %% [markdown]
# ## Exercise 7.1
#
# Explain why it is useful to have your data in tidy format in the context of hierarchical modeling.

# %% [markdown]
# <br/>

# %% [markdown]
# ## Exercise 7.2
#
# Have you encountered a set of experiments that have a hierarchical structure in your own work? If so, can you please briefly describe the situation?

# %% [markdown]
# <br />

# %% [markdown]
# ## Exercise 7.3
#
# What is exchangeability?

# %% [markdown]
# <br />

# %% [markdown]
# ## Exercise 7.4
#
# Describe why thoroughly checking MCMC diagnostics is especially important when working with hierarchical models.

# %% [markdown]
# <br/>

# %% [markdown]
# ## Exercise 7.5
#
# Write down any additional questions you have.
